# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
#pip install pybtex
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "conference": {
        "file" : "proceedings.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    },
    'patent': {
        "file": "patents.bib",
        "venuekey" : "note",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    }
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
keys = set()

for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])
    print(pubsource)
    #loop through the individual references in a given bibtex file
    if keys.intersection(bibdata.entries):
        print(keys.intersection(bibdata.entries))
    keys = keys.union(bibdata.entries)

parser = bibtex.Parser()
all = parser.parse_file("scholar.bib")
for bib_id in all.entries:
    if bib_id not in keys:
        print(bib_id, all.entries[bib_id].type, all.entries[bib_id].fields.get('note'))
# Out:
# conference
# journal
# patent
# vegh2019user misc US Patent App. 16/182,052
# femiani2009document book None
# vegh2023post misc US Patent App. 18/057,296

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
        except FileNotFoundError as e:
            print(f'WARNING Unable to generate file for {bib_id}')
            continue
# Out:
# SUCESSFULLY PARSED amresh2013evaluating: " Evaluating the effectiveness of flipped classrooms for teach ... "
# SUCESSFULLY PARSED che2019segmentation: " Segmentation of Color-Coded Underground Utility Markings  "
# SUCESSFULLY PARSED chuang2012topology: " Topology Free Automated Landmark Detection  "
# SUCESSFULLY PARSED femiani2009interval: " Interval HSV: Extracting ink annotations  "
# SUCESSFULLY PARSED shenoy2017adaptive: " An adaptive time reduction technique for video lectures  "
# SUCESSFULLY PARSED shah2013improving: " Improving E-Learning Videos Using Personalization and Social ... "
# SUCESSFULLY PARSED amresh2012methods: " Methods for approximating Loop subdivision using tessellatio ... "
# SUCESSFULLY PARSED uppalapati20093d: " 3D VQI: 3D visual query interface  "
# SUCESSFULLY PARSED shakeel2018automatic: " Automatic Sign Detection with Application to an Assistive Ro ... "
# SUCESSFULLY PARSED amresh2013uav: " UAV sensor operator training enhancement through heat map an ... "
# SUCESSFULLY PARSED femiani12005system: " A System for Discriminating Handwriting from Machine Print o ... "
# SUCESSFULLY PARSED yin2011new: " A new qem for parametrization of raster images  "
# SUCESSFULLY PARSED liu2018fine: " Fine scale registration of walking paths and other ribbon-li ... "
# SUCESSFULLY PARSED goodenberger2013functional: " Functional morphology of the primate hallucal metatarsal (Mt ... "
# SUCESSFULLY PARSED hu2007fourier: " Fourier shape descriptors of pixel footprints for road extra ... "
# SUCESSFULLY PARSED chuang2015role: " The Role of Certainty and Time Delay in Students' Cheating D ... "
# SUCESSFULLY PARSED abdal2022clip2stylegan: " Clip2stylegan: Unsupervised extraction of stylegan edit dire ... "
# SUCESSFULLY PARSED zhu2022hairnet: " Hairnet: Hairstyle transfer with pose changes  "
# SUCESSFULLY PARSED tocheri2006quadric: " Quadric-based metrics for shape analysis of three-dimensiona ... "
# SUCESSFULLY PARSED li2015robust: " Robust rooftop extraction from visible band images using hig ... "
# SUCESSFULLY PARSED marzke2010comparative: " Comparative 3D quantitative analyses of trapeziometacarpal j ... "
# SUCESSFULLY PARSED marzke2012three: " Three-dimensional quantitative comparative analysis of trape ... "
# SUCESSFULLY PARSED femiani2004curve: " Curve shapes: Comparison and alignment  "
# SUCESSFULLY PARSED jiao2014hybrid: " A hybrid method for multi-sensor remote sensing image regist ... "
# SUCESSFULLY PARSED femiani2010least: " Least Eccentric Curves  "
# SUCESSFULLY PARSED cui2009curve: " Curve matching for open 2D curves  "
# SUCESSFULLY PARSED kelly2017bigsur: " BigSUR: Large-scale structured urban reconstruction  "
# SUCESSFULLY PARSED femiani2018facade: " Facade segmentation in the wild  "
# SUCESSFULLY PARSED chang2018shortcut: " Shortcut to Adiabaticity for Harmonic and Anharmonic Traps u ... "
# SUCESSFULLY PARSED hu2007road: " Road network extraction and intersection detection from aeri ... "
# SUCESSFULLY PARSED chuang2017detecting: " Detecting probable cheating during online assessments based  ... "
# SUCESSFULLY PARSED zhang20063d: " 3D face authentication and recognition based on bilateral sy ... "
# SUCESSFULLY PARSED femiani2014shadow: " Shadow-based rooftop segmentation in visible band images  "
# SUCESSFULLY PARSED femiani2012least: " Least eccentric ellipses for geometric Hermite interpolation  "
# SUCESSFULLY PARSED chang2019trajectory: " Trajectory Simulation and Optimization for Shortcuts to Adia ... "
# SUCESSFULLY PARSED tocheri2011ecological: " Ecological divergence and medial cuneiform morphology in gor ... "
# SUCESSFULLY PARSED hu2007urban: " Urban road network extraction and intersection detection in  ... "
# WARNING Unable to generate file for marzke2012erratum
# SUCESSFULLY PARSED goodenberger2015functional: " Functional morphology of the hallucal metatarsal with implic ... "
# SUCESSFULLY PARSED bae2010semi: " Semi-Automatic Hole Filling Guided by Hermite Curves  "
# WARNING Missing Expected Field 'year' from entry femianidocument: " A Document Image Truthing Tool  "
# SUCESSFULLY PARSED zhu2020large: " Large-Scale Architectural Asset Extraction from Panoramic Im ... "
# SUCESSFULLY PARSED zhu2020improved: " Improved stylegan embedding: Where are the good latents?  "
# SUCESSFULLY PARSED zhu2021mind: " Mind the gap: Domain gap control for single shot domain adap ... "
# SUCESSFULLY PARSED zhu2021barbershop: " Barbershop: Gan-based image compositing using segmentation m ... "
# WARNING Missing Expected Field 'patent' from entry razdan2010comparative: " Comparative and analytic appar ... "
# WARNING Missing Expected Field 'patent' from entry vegh2018post: " Post capture imagery processin ... "
# WARNING Missing Expected Field 'patent' from entry vegh2018user: " User interaction event data ca ... "
# WARNING Missing Expected Field 'patent' from entry vegh2019post: " Post capture imagery processin ... "
# WARNING Missing Expected Field 'patent' from entry razden2014methods: " Methods and System for Monitor ... "
